# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# %load_ext autoreload
# %autoreload 2
# Out:
# <style>.container { width:90% !important; }</style>

# %%
from sympy import (
    Derivative, 
    S, 
    Symbol, 
    series, 
    sqrt, 
    symbols, 
    oo, 
    limit, 
    Rational, 
    cos, 
    sin, 
    cosh, 
    sinh, 
    Matrix, 
    simplify, 
    latex, 
    lambdify,
    Function,
    collect,
    lambdify,
    solve,
    Eq,
    Poly,
    Derivative,
    together,
)
from sympy.core.numbers import NegativeOne, One, Zero
import numpy as np
import pandas as pd
from sympy import init_printing
init_printing() 

from sympy.printing.latex import print_latex
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
from matplotlib import cm
# %matplotlib notebook
from pymad_hzb.PlotTools import new_plot_elems_madx
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
from matplotlib import cm

# %%
from acchamiltoniansandmatrices.Matrices.SymbMatrices import (
    RsymbFODO, 
    RsymbDrift6D, 
    RsymbQuad6D, 
    RsymbQuad6DChroma, 
    RsymbQuad6DThin
)
from acchamiltoniansandmatrices.Matrices.NumpyMatrices import (
    RnpFODO, 
    RnpDrift6D, 
    RnpQuad6D, 
    RnpQuad6DChroma, 
    RnpQuad6DThin
)
from acchamiltoniansandmatrices.Hamiltonians.LatticeElementHamiltonians import (
    HamDrift6D, 
    HamDrift6DParaxialSecondOrder, 
    HamQuad6D, 
    HamQuad6DParaxialSecondOrder, 
    HamQuad6DParaxialSecondOrderChroma,
)
from acchamiltoniansandmatrices.Hamiltonians.Operators import Poisson
from acchamiltoniansandmatrices.Tracking.LinearMatrixTracking import nestList, LinMap, GenerateNDimCoordinateGrid
from acchamiltoniansandmatrices.LieMaps.LieOperator import LieOperator
from acchamiltoniansandmatrices.LieMaps.Poisson import PoissonBracket

from acchamiltoniansandmatrices.Utils.JupyterHelpFunctions import hide_toggle
from acchamiltoniansandmatrices.Utils.SymbolicFunctions import SymbolTrick, fixedpoints2D
from acchamiltoniansandmatrices.Utils.Plotting import multi_countour_plot

# %%
x, px, y, py, z, delta, eps, h , k0, k1, k2, sigma, betag ,f = symbols('x p_x y p_y z delta epsilon h k_0 k_1 k_2 sigma beta_gamma f', real=True)
L, beta0, gamma0 = symbols(" L beta_0 gamma_0", real=True, positive=True)

# %%
A = Function("A", commutative=False)(x,px)
B = Function("B", commutative=False)(x,px)
C = Function("C", commutative=False)(x,px)
D = Function("D", commutative=False)(x,px)
E = Function("E", commutative=False)(x,px)

Aop = LieOperator(A,x,px)
Bop = LieOperator(B,x,px)
Cop = LieOperator(C,x,px)
Dop = LieOperator(D,x,px)
Eop = LieOperator(E,x,px)

# %%
# Define constant number symbols in sympy - otherwise they are considered variables
LQF   = SymbolTrick("L_{QF}")
LQD   = SymbolTrick("L_{QD}")
LD    = SymbolTrick("L_D")
KQF   = SymbolTrick("K_{QF}")
KQD   = SymbolTrick("K_{QD}")

rep = list(zip(
    [
        LD,
        LQF,
        LQD,
        KQF,
        KQD,
        delta
    ],
    [
        3.5805,
        0.342,
        0.668,
        0.49,
        -0.4999,
        1.5e-3
    ]
)
          )

hamd  = NegativeOne() * HamDrift6D(beta0, gamma0, LD,x,px,y,py,delta).subs(beta0*gamma0,oo).subs(beta0,One()).subs(delta,1.5e-3)
hamqf = NegativeOne() * Rational(1,2) * HamQuad6DParaxialSecondOrder(beta0,gamma0,LQF,x,px,y,py,delta,KQF).subs(delta,Zero())
hamqd = NegativeOne() * HamQuad6DParaxialSecondOrder(beta0,gamma0,LQD,x,px,y,py,delta,KQD).subs(delta,Zero())

# %%
hamd
# Out:
#      ⎛                   _____________________________________________________
#      ⎜                  ╱                       2                        2
# -L_D⋅⎝0.0015 - 1.0015⋅╲╱  - 0.997006736525267⋅pₓ  - 0.997006736525267⋅p_y  + 1
#
# _⎞
#  ⎟
#  ⎠

# %%
hamqf.collect(KQF)
# Out:
#         ⎛  2      2          ⎛ 2    2⎞⎞
#         ⎜pₓ    p_y           ⎜x    y ⎟⎟
# -L_{QF}⋅⎜─── + ──── + K_{QF}⋅⎜── - ──⎟⎟
#         ⎝ 2     2            ⎝2    2 ⎠⎠
# ────────────────────────────────────────
#                    2

# %%
hamqd.collect(KQD)
# Out:
#         ⎛  2      2          ⎛ 2    2⎞⎞
#         ⎜pₓ    p_y           ⎜x    y ⎟⎟
# -L_{QD}⋅⎜─── + ──── + K_{QD}⋅⎜── - ──⎟⎟
#         ⎝ 2     2            ⎝2    2 ⎠⎠

# %%
o = 1
ham1     = Aop.BCH(Bop,o).BCH(Cop,o).BCH(Dop,o).BCH(Eop,o).ham
fodoham1 = ham1.subs(A,hamqf).subs(B,hamd).subs(C,hamqd).subs(D,hamd).subs(E,hamqf).doit()
o = 2
ham2     = Aop.BCH(Bop,o).BCH(Cop,o).BCH(Dop,o).BCH(Eop,o).ham
fodoham2 = ham2.subs(A,hamqf).subs(B,hamd).subs(C,hamqd).subs(D,hamd).subs(E,hamqf).doit()

# %%
ham1
# Out:
# A(x, pₓ) + B(x, pₓ) + C(x, pₓ) + D(x, pₓ) + E(x, pₓ)

# %%
fodoham1
# Out:
#         ⎛                   __________________________________________________
#         ⎜                  ╱                       2                        2
# - 2⋅L_D⋅⎝0.0015 - 1.0015⋅╲╱  - 0.997006736525267⋅pₓ  - 0.997006736525267⋅p_y
#
#
# ____⎞          ⎛  2      2    2           2       ⎞          ⎛  2      2    2
#     ⎟          ⎜pₓ    p_y    x ⋅K_{QD}   y ⋅K_{QD}⎟          ⎜pₓ    p_y    x ⋅
# + 1 ⎠ - L_{QD}⋅⎜─── + ──── + ───────── - ─────────⎟ - L_{QF}⋅⎜─── + ──── + ───
#                ⎝ 2     2         2           2    ⎠          ⎝ 2     2
#
#           2       ⎞
# K_{QF}   y ⋅K_{QF}⎟
# ────── - ─────────⎟
#  2           2    ⎠

# %%
ham2.expand(commutator=True)
# Out:
#                                                        PoissonBracket(A(x, p_x
# A(x, pₓ) + B(x, pₓ) + C(x, pₓ) + D(x, pₓ) + E(x, pₓ) + ───────────────────────
#                                                                         2
#
# ), B(x, p_x))   PoissonBracket(A(x, p_x), C(x, p_x))   PoissonBracket(A(x, p_x
# ───────────── + ──────────────────────────────────── + ───────────────────────
#                                  2                                      2
#
# ), D(x, p_x))   PoissonBracket(A(x, p_x), E(x, p_x))   PoissonBracket(B(x, p_x
# ───────────── + ──────────────────────────────────── + ───────────────────────
#                                  2                                      2
#
# ), C(x, p_x))   PoissonBracket(B(x, p_x), D(x, p_x))   PoissonBracket(B(x, p_x
# ───────────── + ──────────────────────────────────── + ───────────────────────
#                                  2                                      2
#
# ), E(x, p_x))   PoissonBracket(C(x, p_x), D(x, p_x))   PoissonBracket(C(x, p_x
# ───────────── + ──────────────────────────────────── + ───────────────────────
#                                  2                                      2
#
# ), E(x, p_x))   PoissonBracket(C(x, p_x), PoissonBracket(A(x, p_x), B(x, p_x))
# ───────────── - ──────────────────────────────────────────────────────────────
#                                                4
#
# )   PoissonBracket(D(x, p_x), E(x, p_x))   PoissonBracket(D(x, p_x), PoissonBr
# ─ + ──────────────────────────────────── - ───────────────────────────────────
#                      2                                                    4
#
# acket(A(x, p_x), B(x, p_x)))   PoissonBracket(D(x, p_x), PoissonBracket(A(x, p
# ──────────────────────────── - ───────────────────────────────────────────────
#                                                               4
#
# _x), C(x, p_x)))   PoissonBracket(D(x, p_x), PoissonBracket(B(x, p_x), C(x, p_
# ──────────────── - ───────────────────────────────────────────────────────────
#                                                   4
#
# x)))   PoissonBracket(D(x, p_x), PoissonBracket(C(x, p_x), PoissonBracket(A(x,
# ──── + ───────────────────────────────────────────────────────────────────────
#                                                    8
#
#  p_x), B(x, p_x))))   PoissonBracket(E(x, p_x), PoissonBracket(A(x, p_x), B(x,
# ─────────────────── - ────────────────────────────────────────────────────────
#                                                      4
#
#  p_x)))   PoissonBracket(E(x, p_x), PoissonBracket(A(x, p_x), C(x, p_x)))   Po
# ─────── - ─────────────────────────────────────────────────────────────── - ──
#                                          4
#
# issonBracket(E(x, p_x), PoissonBracket(A(x, p_x), D(x, p_x)))   PoissonBracket
# ───────────────────────────────────────────────────────────── - ──────────────
#                              4
#
# (E(x, p_x), PoissonBracket(B(x, p_x), C(x, p_x)))   PoissonBracket(E(x, p_x),
# ───────────────────────────────────────────────── - ──────────────────────────
#                  4
#
# PoissonBracket(B(x, p_x), D(x, p_x)))   PoissonBracket(E(x, p_x), PoissonBrack
# ───────────────────────────────────── - ──────────────────────────────────────
#      4                                                                 4
#
# et(C(x, p_x), D(x, p_x)))   PoissonBracket(E(x, p_x), PoissonBracket(C(x, p_x)
# ───────────────────────── + ──────────────────────────────────────────────────
#                                                                         8
#
# , PoissonBracket(A(x, p_x), B(x, p_x))))   PoissonBracket(E(x, p_x), PoissonBr
# ──────────────────────────────────────── + ───────────────────────────────────
#
#
# acket(D(x, p_x), PoissonBracket(A(x, p_x), B(x, p_x))))   PoissonBracket(E(x,
# ─────────────────────────────────────────────────────── + ────────────────────
#          8
#
# p_x), PoissonBracket(D(x, p_x), PoissonBracket(A(x, p_x), C(x, p_x))))   Poiss
# ────────────────────────────────────────────────────────────────────── + ─────
#                         8
#
# onBracket(E(x, p_x), PoissonBracket(D(x, p_x), PoissonBracket(B(x, p_x), C(x,
# ──────────────────────────────────────────────────────────────────────────────
#                                        8
#
# p_x))))   PoissonBracket(E(x, p_x), PoissonBracket(D(x, p_x), PoissonBracket(C
# ─────── - ────────────────────────────────────────────────────────────────────
#                                                                     16
#
# (x, p_x), PoissonBracket(A(x, p_x), B(x, p_x)))))
# ─────────────────────────────────────────────────

# %%
ham2     = Aop.BCH(Bop,o).BCH(Cop,o).BCH(Bop,o).BCH(Aop,o).ham
fodoham2 = ham2.subs(A,hamqf).subs(B,hamd).subs(C,hamqd).doit()

# %%
ham2.expand(commutator=True)
# Out:
#                                      PoissonBracket(A(x, p_x), PoissonBracket(
# 2⋅A(x, pₓ) + 2⋅B(x, pₓ) + C(x, pₓ) - ─────────────────────────────────────────
#                                                                     2
#
# A(x, p_x), B(x, p_x)))   PoissonBracket(A(x, p_x), PoissonBracket(A(x, p_x), C
# ────────────────────── - ─────────────────────────────────────────────────────
#                                                         4
#
# (x, p_x)))   PoissonBracket(A(x, p_x), PoissonBracket(B(x, p_x), PoissonBracke
# ────────── + ─────────────────────────────────────────────────────────────────
#                                                          8
#
# t(A(x, p_x), B(x, p_x))))   PoissonBracket(A(x, p_x), PoissonBracket(B(x, p_x)
# ───────────────────────── + ──────────────────────────────────────────────────
#                                                                         8
#
# , PoissonBracket(A(x, p_x), C(x, p_x))))   PoissonBracket(A(x, p_x), PoissonBr
# ──────────────────────────────────────── + ───────────────────────────────────
#
#
# acket(B(x, p_x), PoissonBracket(B(x, p_x), C(x, p_x))))   PoissonBracket(A(x,
# ─────────────────────────────────────────────────────── - ────────────────────
#          8
#
# p_x), PoissonBracket(B(x, p_x), PoissonBracket(C(x, p_x), PoissonBracket(A(x,
# ──────────────────────────────────────────────────────────────────────────────
#                                       16
#
# p_x), B(x, p_x)))))   PoissonBracket(A(x, p_x), PoissonBracket(C(x, p_x), Pois
# ─────────────────── + ────────────────────────────────────────────────────────
#                                                                   8
#
# sonBracket(A(x, p_x), B(x, p_x))))   PoissonBracket(B(x, p_x), PoissonBracket(
# ────────────────────────────────── - ─────────────────────────────────────────
#                                                                     4
#
# A(x, p_x), B(x, p_x)))   PoissonBracket(B(x, p_x), PoissonBracket(A(x, p_x), C
# ────────────────────── - ─────────────────────────────────────────────────────
#                                                         4
#
# (x, p_x)))   PoissonBracket(B(x, p_x), PoissonBracket(B(x, p_x), C(x, p_x)))
# ────────── - ─────────────────────────────────────────────────────────────── +
#                                             4
#
#  PoissonBracket(B(x, p_x), PoissonBracket(C(x, p_x), PoissonBracket(A(x, p_x),
#  ─────────────────────────────────────────────────────────────────────────────
#                                              8
#
#  B(x, p_x))))   PoissonBracket(C(x, p_x), PoissonBracket(A(x, p_x), B(x, p_x))
# ───────────── - ──────────────────────────────────────────────────────────────
#                                                4
#
# )
# ─

# %%
fodoham2expanded = fodoham2.expand(commutator=True)
fodoham2expanded
# Out:
#
#
# - ────────────────────────────────────────────────────────────────────────────
#                         6                     4    2                      4
#   - 0.991047061635966⋅pₓ  - 2.9731411849079⋅pₓ ⋅p_y  + 2.98206729803029⋅pₓ  -
#
#
#                             4  2              2    2              2
#        0.0929106620283718⋅pₓ ⋅x ⋅K_{QD}⋅K_{QF} ⋅L_D ⋅L_{QD}⋅L_{QF}
# ──────────────────────────────────────────────────────────────────────────────
#                   2    4                      2    2                     2
# 2.9731411849079⋅pₓ ⋅p_y  + 5.96413459606058⋅pₓ ⋅p_y  - 2.9910202095758⋅pₓ  - 0
#
#
#
#
# ──────────────────────────────────────────────────────────────────────── - ───
#                     6                       4                      2
# .991047061635966⋅p_y  + 2.98206729803029⋅p_y  - 2.9910202095758⋅p_y  + 1   - 0
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#                    6                     4    2                      4
# .991047061635966⋅pₓ  - 2.9731411849079⋅pₓ ⋅p_y  + 2.98206729803029⋅pₓ  - 2.973
#
#
#                        4  2              2    2              2
#   0.0309702206761239⋅pₓ ⋅x ⋅K_{QD}⋅K_{QF} ⋅L_D ⋅L_{QD}⋅L_{QF}
# ──────────────────────────────────────────────────────────────────────────────
#              2    4                      2    2                     2
# 1411849079⋅pₓ ⋅p_y  + 5.96413459606058⋅pₓ ⋅p_y  - 2.9910202095758⋅pₓ  - 0.9910
#
#
#
#
# ─────────────────────────────────────────────────────────────────── + ────────
#                6                       4                      2
# 47061635966⋅p_y  + 2.98206729803029⋅p_y  - 2.9910202095758⋅p_y  + 1   0.994022
#
#
#                                                 4                  2
#                            0.0310632010211488⋅pₓ ⋅K_{QD}⋅K_{QF}⋅L_D ⋅L_{QD}⋅L_
# ──────────────────────────────────────────────────────────────────────────────
#             4                      2    2                      2
# 432676763⋅pₓ  + 1.98804486535353⋅pₓ ⋅p_y  - 1.99401347305053⋅pₓ  + 0.994022432
#
#
#     2
# {QF}
# ─────────────────────────────────────── + ────────────────────────────────────
#           4                       2                                ___________
# 676763⋅p_y  - 1.99401347305053⋅p_y  + 1                       4   ╱
#                                           0.994022432676763⋅pₓ ⋅╲╱  - 0.997006
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
# ___________________________________________                                ___
#             2                        2                           2    2   ╱
# 736525267⋅pₓ  - 0.997006736525267⋅p_y  + 1  + 1.98804486535353⋅pₓ ⋅p_y ⋅╲╱  -
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
# ___________________________________________________
#                     2                        2                           2   ╱
# 0.997006736525267⋅pₓ  - 0.997006736525267⋅p_y  + 1  - 1.99401347305053⋅pₓ ⋅╲╱
#
#                                    3  3              2                  2
#               0.0930500280214144⋅pₓ ⋅x ⋅K_{QD}⋅K_{QF} ⋅L_D⋅L_{QD}⋅L_{QF}
# ──────────────────────────────────────────────────────────────────────────────
# ______________________________________________________
#                        2                        2
#  - 0.997006736525267⋅pₓ  - 0.997006736525267⋅p_y  + 1  + 0.994022432676763⋅p_y
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#      ______________________________________________________
# 4   ╱                       2                        2
#  ⋅╲╱  - 0.997006736525267⋅pₓ  - 0.997006736525267⋅p_y  + 1  - 1.99401347305053
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#          ______________________________________________________      _________
#     2   ╱                       2                        2          ╱
# ⋅p_y ⋅╲╱  - 0.997006736525267⋅pₓ  - 0.997006736525267⋅p_y  + 1  + ╲╱  - 0.9970
#
#
#
# ───────────────────────────────────────────── - ──────────────────────────────
# _____________________________________________                       4
#               2                        2        0.994022432676763⋅pₓ  + 1.9880
# 06736525267⋅pₓ  - 0.997006736525267⋅p_y  + 1
#
#                          3                    2
#     0.0621264020422977⋅pₓ ⋅x⋅K_{QD}⋅K_{QF}⋅L_D ⋅L_{QD}⋅L_{QF}
# ──────────────────────────────────────────────────────────────────────────────
#              2    2                      2                        4
# 4486535353⋅pₓ ⋅p_y  - 1.99401347305053⋅pₓ  + 0.994022432676763⋅p_y  - 1.994013
#
#
#                                                                            3
#                                                       0.0621264020422977⋅pₓ ⋅x
# ───────────────── - ──────────────────────────────────────────────────────────
#             2                           4                      2    2
# 47305053⋅p_y  + 1   0.994022432676763⋅pₓ  + 1.98804486535353⋅pₓ ⋅p_y  - 1.9940
#
#
#                   2
# ⋅K_{QD}⋅K_{QF}⋅L_D ⋅L_{QD}⋅L_{QF}
# ─────────────────────────────────────────────────────────────────── + ────────
#              2                        4                       2
# 1347305053⋅pₓ  + 0.994022432676763⋅p_y  - 1.99401347305053⋅p_y  + 1   0.994022
#
#
#                                                3                    2
#                           0.0621264020422977⋅pₓ ⋅x⋅K_{QD}⋅K_{QF}⋅L_D ⋅L_{QD}⋅L
# ──────────────────────────────────────────────────────────────────────────────
#             4                      2    2                      2
# 432676763⋅pₓ  + 1.98804486535353⋅pₓ ⋅p_y  - 1.99401347305053⋅pₓ  + 0.994022432
#
#
#
# _{QF}                                                                       0.
# ─────────────────────────────────────── + ────────────────────────────────────
#           4                       2                           4
# 676763⋅p_y  - 1.99401347305053⋅p_y  + 1   0.994022432676763⋅pₓ  + 1.9880448653
#
#
#                    3                    2
# 0621264020422977⋅pₓ ⋅x⋅K_{QD}⋅K_{QF}⋅L_D ⋅L_{QD}⋅L_{QF}
# ──────────────────────────────────────────────────────────────────────────────
#        2    2                      2                        4
# 5353⋅pₓ ⋅p_y  - 1.99401347305053⋅pₓ  + 0.994022432676763⋅p_y  - 1.994013473050
#
#
#
#
# ─────────── - ────────────────────────────────────────────────────────────────
#       2                                  _____________________________________
# 53⋅p_y  + 1                         2   ╱                       2
#               - 0.997006736525267⋅pₓ ⋅╲╱  - 0.997006736525267⋅pₓ  - 0.99700673
#
#                                         3                                  2
#                    0.0311097958226806⋅pₓ ⋅x⋅K_{QD}⋅K_{QF}⋅L_D⋅L_{QD}⋅L_{QF}
# ──────────────────────────────────────────────────────────────────────────────
# _________________                             ________________________________
#            2                             2   ╱                       2
# 6525267⋅p_y  + 1  - 0.997006736525267⋅p_y ⋅╲╱  - 0.997006736525267⋅pₓ  - 0.997
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
# ______________________      __________________________________________________
#                 2          ╱                       2                        2
# 006736525267⋅p_y  + 1  + ╲╱  - 0.997006736525267⋅pₓ  - 0.997006736525267⋅p_y
#
#
#
# ──── - ───────────────────────────────────────────────────────────────────────
# ____                              ____________________________________________
#                              2   ╱                       2
# + 1    - 0.997006736525267⋅pₓ ⋅╲╱  - 0.997006736525267⋅pₓ  - 0.997006736525267
#
#                                  3                                  2
#             0.0311097958226806⋅pₓ ⋅x⋅K_{QD}⋅K_{QF}⋅L_D⋅L_{QD}⋅L_{QF}
# ──────────────────────────────────────────────────────────────────────────────
# __________                             _______________________________________
#     2                             2   ╱                       2
# ⋅p_y  + 1  - 0.997006736525267⋅p_y ⋅╲╱  - 0.997006736525267⋅pₓ  - 0.9970067365
#
#
#
# ─────────────────────────────────────────────────────────────────────────── +
# _______________      ______________________________________________________
#          2          ╱                       2                        2
# 25267⋅p_y  + 1  + ╲╱  - 0.997006736525267⋅pₓ  - 0.997006736525267⋅p_y  + 1
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#                            ___________________________________________________
#                       2   ╱                       2                        2
# - 0.997006736525267⋅pₓ ⋅╲╱  - 0.997006736525267⋅pₓ  - 0.997006736525267⋅p_y  +
#
#                           3                                  2
#      0.0311097958226806⋅pₓ ⋅x⋅K_{QD}⋅K_{QF}⋅L_D⋅L_{QD}⋅L_{QF}
# ──────────────────────────────────────────────────────────────────────────────
# ___                             ______________________________________________
#                            2   ╱                       2
#  1  - 0.997006736525267⋅p_y ⋅╲╱  - 0.997006736525267⋅pₓ  - 0.997006736525267⋅p
#
#
#
# ──────────────────────────────────────────────────────────────────── - ───────
# ________      ______________________________________________________
#   2          ╱                       2                        2        0.99402
# _y  + 1  + ╲╱  - 0.997006736525267⋅pₓ  - 0.997006736525267⋅p_y  + 1
#
#                                                       3         2    2       2
#                                  0.0621264020422977⋅pₓ ⋅x⋅K_{QF} ⋅L_D ⋅L_{QF}
# ──────────────────────────────────────────────────────────────────────────────
#              4                      2    2                      2
# 2432676763⋅pₓ  + 1.98804486535353⋅pₓ ⋅p_y  - 1.99401347305053⋅pₓ  + 0.99402243
#
#
#
#
# ──────────────────────────────────────── - ───────────────────────────────────
#            4                       2                                  ________
# 2676763⋅p_y  - 1.99401347305053⋅p_y  + 1                         2   ╱
#                                            - 0.997006736525267⋅pₓ ⋅╲╱  - 0.997
#
#                                                                         3
#                                                    0.0311097958226806⋅pₓ ⋅x⋅K_
# ──────────────────────────────────────────────────────────────────────────────
# ______________________________________________                             ___
#                2                        2                             2   ╱
# 006736525267⋅pₓ  - 0.997006736525267⋅p_y  + 1  - 0.997006736525267⋅p_y ⋅╲╱  -
#
#     2                  2
# {QF} ⋅L_D⋅L_{QD}⋅L_{QF}
# ──────────────────────────────────────────────────────────────────────────────
# ___________________________________________________      _____________________
#                     2                        2          ╱
# 0.997006736525267⋅pₓ  - 0.997006736525267⋅p_y  + 1  + ╲╱  - 0.997006736525267⋅
#
#
#
# ───────────────────────────────── - ──────────────────────────────────────────
# _________________________________                              _______________
#   2                        2                              2   ╱
# pₓ  - 0.997006736525267⋅p_y  + 1    - 0.997006736525267⋅pₓ ⋅╲╱  - 0.9970067365
#
#                                                                  3         2
#                                             0.0311097958226806⋅pₓ ⋅x⋅K_{QF} ⋅L
# ──────────────────────────────────────────────────────────────────────────────
# _______________________________________                             __________
#         2                        2                             2   ╱
# 25267⋅pₓ  - 0.997006736525267⋅p_y  + 1  - 0.997006736525267⋅p_y ⋅╲╱  - 0.99700
#
#                 2
# _D⋅L_{QD}⋅L_{QF}
# ──────────────────────────────────────────────────────────────────────────────
# ____________________________________________      ____________________________
#              2                        2          ╱                       2
# 6736525267⋅pₓ  - 0.997006736525267⋅p_y  + 1  + ╲╱  - 0.997006736525267⋅pₓ  - 0
#
#
#                                                               0.09318960306344
# ────────────────────────── - ─────────────────────────────────────────────────
# __________________________                       4                      2    2
#                     2        0.994022432676763⋅pₓ  + 1.98804486535353⋅pₓ ⋅p_y
# .997006736525267⋅p_y  + 1
#
#      2  2              2    2              2
# 65⋅pₓ ⋅x ⋅K_{QD}⋅K_{QF} ⋅L_D ⋅L_{QD}⋅L_{QF}
# ──────────────────────────────────────────────────────────────────────────── -
#                       2                        4                       2
#  - 1.99401347305053⋅pₓ  + 0.994022432676763⋅p_y  - 1.99401347305053⋅p_y  + 1
#
#
#                                                        2  2              2
#                                   0.0621264020422977⋅pₓ ⋅x ⋅K_{QD}⋅K_{QF} ⋅L_D
#  ─────────────────────────────────────────────────────────────────────────────
#                      4                      2    2                      2
#  0.994022432676763⋅pₓ  + 1.98804486535353⋅pₓ ⋅p_y  - 1.99401347305053⋅pₓ  + 0.
#
#
# 2              2
#  ⋅L_{QD}⋅L_{QF}
# ──────────────────────────────────────────────── - ───────────────────────────
#                    4                       2
# 994022432676763⋅p_y  - 1.99401347305053⋅p_y  + 1                         2   ╱
#                                                    - 0.997006736525267⋅pₓ ⋅╲╱
#
#                                                                              2
#                                                          0.124439183290722⋅pₓ
# ──────────────────────────────────────────────────────────────────────────────
# ______________________________________________________
#                        2                        2
#  - 0.997006736525267⋅pₓ  - 0.997006736525267⋅p_y  + 1  - 0.997006736525267⋅p_y
#
#   2
# ⋅x ⋅K_{QD}⋅K_{QF}⋅L_D⋅L_{QD}⋅L_{QF}
# ──────────────────────────────────────────────────────────────────────────────
#      ______________________________________________________      _____________
# 2   ╱                       2                        2          ╱
#  ⋅╲╱  - 0.997006736525267⋅pₓ  - 0.997006736525267⋅p_y  + 1  + ╲╱  - 0.99700673
#
#
#
# ───────────────────────────────────────── + ──────────────────────────────────
# _________________________________________                              _______
#           2                        2                              2   ╱
# 6525267⋅pₓ  - 0.997006736525267⋅p_y  + 1    - 0.997006736525267⋅pₓ ⋅╲╱  - 0.99
#
#                                                                       2  2
#                                                   0.124439183290722⋅pₓ ⋅x ⋅K_{
# ──────────────────────────────────────────────────────────────────────────────
# _______________________________________________                             __
#                 2                        2                             2   ╱
# 7006736525267⋅pₓ  - 0.997006736525267⋅p_y  + 1  - 0.997006736525267⋅p_y ⋅╲╱  -
#
#
# QD}⋅K_{QF}⋅L_D⋅L_{QD}⋅L_{QF}
# ──────────────────────────────────────────────────────────────────────────────
# ____________________________________________________      ____________________
#                      2                        2          ╱
#  0.997006736525267⋅pₓ  - 0.997006736525267⋅p_y  + 1  + ╲╱  - 0.997006736525267
#
#
#
# ────────────────────────────────── + ─────────────────────────────────────────
# __________________________________                              ______________
#    2                        2                              2   ╱
# ⋅pₓ  - 0.997006736525267⋅p_y  + 1    - 0.997006736525267⋅pₓ ⋅╲╱  - 0.997006736
#
#                                                                2  2
#                                            0.124439183290722⋅pₓ ⋅x ⋅K_{QD}⋅K_{
# ──────────────────────────────────────────────────────────────────────────────
# ________________________________________                             _________
#          2                        2                             2   ╱
# 525267⋅pₓ  - 0.997006736525267⋅p_y  + 1  - 0.997006736525267⋅p_y ⋅╲╱  - 0.9970
#
#
# QF}⋅L_D⋅L_{QD}⋅L_{QF}
# ──────────────────────────────────────────────────────────────────────────────
# _____________________________________________      ___________________________
#               2                        2          ╱                       2
# 06736525267⋅pₓ  - 0.997006736525267⋅p_y  + 1  + ╲╱  - 0.997006736525267⋅pₓ  -
#
#
#
# ─────────────────────────── + ────────────────────────────────────────────────
# ___________________________                              _____________________
#                      2                              2   ╱
# 0.997006736525267⋅p_y  + 1    - 0.997006736525267⋅pₓ ⋅╲╱  - 0.997006736525267⋅
#
#                                                               2  2       2
#                                           0.124439183290722⋅pₓ ⋅x ⋅K_{QF} ⋅L_D
# ──────────────────────────────────────────────────────────────────────────────
# _________________________________                             ________________
#   2                        2                             2   ╱
# pₓ  - 0.997006736525267⋅p_y  + 1  - 0.997006736525267⋅p_y ⋅╲╱  - 0.99700673652
#
#        2
# ⋅L_{QF}
# ──────────────────────────────────────────────────────────────────────────────
# ______________________________________      __________________________________
#        2                        2          ╱                       2
# 5267⋅pₓ  - 0.997006736525267⋅p_y  + 1  + ╲╱  - 0.997006736525267⋅pₓ  - 0.99700
#
#                                             2                  2
#                        0.0311564605164146⋅pₓ ⋅K_{QD}⋅K_{QF}⋅L_D ⋅L_{QD}⋅L_{QF}
# ──────────────────── + ───────────────────────────────────────────────────────
# ____________________                           2                        2
#               2          - 0.997006736525267⋅pₓ  - 0.997006736525267⋅p_y  + 1
# 6736525267⋅p_y  + 1
#
# 2                             2           2
#           0.249251684131317⋅pₓ ⋅K_{QD}⋅L_D ⋅L_{QD}               0.12481278082
# ─ + ──────────────────────────────────────────────────── - ───────────────────
#                           2                        2          ________________
#     - 0.997006736525267⋅pₓ  - 0.997006736525267⋅p_y  + 1     ╱
#                                                            ╲╱  - 0.99700673652
#
#        2                                                           2
# 8757⋅pₓ ⋅K_{QD}⋅L_D⋅L_{QD}⋅L_{QF}              0.124812780828757⋅pₓ ⋅K_{QD}⋅L_
# ────────────────────────────────────── + ─────────────────────────────────────
# ______________________________________      __________________________________
#        2                        2          ╱                       2
# 5267⋅pₓ  - 0.997006736525267⋅p_y  + 1    ╲╱  - 0.997006736525267⋅pₓ  - 0.99700
#
#                                                  2
# D⋅L_{QD}⋅L_{QF}              0.124812780828757⋅pₓ ⋅K_{QD}⋅L_D⋅L_{QD}⋅L_{QF}
# ──────────────────── + ───────────────────────────────────────────────────────
# ____________________      ____________________________________________________
#               2          ╱                       2                        2
# 6736525267⋅p_y  + 1    ╲╱  - 0.997006736525267⋅pₓ  - 0.997006736525267⋅p_y  +
#
#        2                     2                             2           2
#      pₓ ⋅K_{QD}⋅L_{QD}⋅L_{QF}          0.124625842065658⋅pₓ ⋅K_{QF}⋅L_D ⋅L_{QF
# ── + ───────────────────────── - ─────────────────────────────────────────────
# __               16                                    2
#                                  - 0.997006736525267⋅pₓ  - 0.997006736525267⋅p
# 1
#
#                                     2
# }               0.124812780828757⋅pₓ ⋅K_{QF}⋅L_D⋅L_{QD}⋅L_{QF}              0.
# ─────── - ───────────────────────────────────────────────────────── - ────────
#   2          ______________________________________________________      _____
# _y  + 1     ╱                       2                        2          ╱
#           ╲╱  - 0.997006736525267⋅pₓ  - 0.997006736525267⋅p_y  + 1    ╲╱  - 0.
#
#                   2
# 124812780828757⋅pₓ ⋅K_{QF}⋅L_D⋅L_{QD}⋅L_{QF}                0.0624063904143784
# ───────────────────────────────────────────────── - ──────────────────────────
# _________________________________________________      _______________________
#                   2                        2          ╱
# 997006736525267⋅pₓ  - 0.997006736525267⋅p_y  + 1    ╲╱  - 0.997006736525267⋅pₓ
#
#    2                  2                                        2
# ⋅pₓ ⋅K_{QF}⋅L_D⋅L_{QF}                    0.0624063904143784⋅pₓ ⋅K_{QF}⋅L_D⋅L_
# ─────────────────────────────── - ────────────────────────────────────────────
# _______________________________      _________________________________________
# 2                        2          ╱                       2
#   - 0.997006736525267⋅p_y  + 1    ╲╱  - 0.997006736525267⋅pₓ  - 0.997006736525
#
#     2             2                     2     2            2
# {QF}            pₓ ⋅K_{QF}⋅L_{QD}⋅L_{QF}    pₓ ⋅L_{QD}   pₓ ⋅L_{QF}
# ───────────── - ───────────────────────── - ────────── - ────────── + ────────
# _____________               16                  2            2
#        2
# 267⋅p_y  + 1                                                          - 0.9970
#
#
#                                                                            0.0
# ──────────────────────────────────────────────────────────────────────────────
#                    ______________________________________________________
#               2   ╱                       2                        2
# 06736525267⋅pₓ ⋅╲╱  - 0.997006736525267⋅pₓ  - 0.997006736525267⋅p_y  + 1  - 0.
#
#                     3              2                  2
# 933293874680417⋅pₓ⋅x ⋅K_{QD}⋅K_{QF} ⋅L_D⋅L_{QD}⋅L_{QF}
# ──────────────────────────────────────────────────────────────────────────────
#                         ______________________________________________________
#                    2   ╱                       2                        2
# 997006736525267⋅p_y ⋅╲╱  - 0.997006736525267⋅pₓ  - 0.997006736525267⋅p_y  + 1
#
#
#                                                                0.0623129210328
# ──────────────────────────────────────────────────────────── - ───────────────
#       ______________________________________________________
#      ╱                       2                        2          - 0.997006736
#  + ╲╱  - 0.997006736525267⋅pₓ  - 0.997006736525267⋅p_y  + 1
#
#                           2
# 292⋅pₓ⋅x⋅K_{QD}⋅K_{QF}⋅L_D ⋅L_{QD}⋅L_{QF}   0.0623129210328292⋅pₓ⋅x⋅K_{QD}⋅K_{
# ───────────────────────────────────────── - ──────────────────────────────────
#          2                        2                                 2
# 525267⋅pₓ  - 0.997006736525267⋅p_y  + 1       - 0.997006736525267⋅pₓ  - 0.9970
#
#
#        2                                                          2
# QF}⋅L_D ⋅L_{QD}⋅L_{QF}   0.0623129210328292⋅pₓ⋅x⋅K_{QD}⋅K_{QF}⋅L_D ⋅L_{QD}⋅L_{
# ────────────────────── + ─────────────────────────────────────────────────────
#                2                                 2                        2
# 06736525267⋅p_y  + 1       - 0.997006736525267⋅pₓ  - 0.997006736525267⋅p_y  +
#
#
#                                                2
# QF}   0.0623129210328292⋅pₓ⋅x⋅K_{QD}⋅K_{QF}⋅L_D ⋅L_{QD}⋅L_{QF}    0.0312031952
# ─── + ──────────────────────────────────────────────────────── - ─────────────
#                               2                        2            __________
# 1       - 0.997006736525267⋅pₓ  - 0.997006736525267⋅p_y  + 1       ╱
#                                                                  ╲╱  - 0.99700
#
#                                            2
# 071892⋅pₓ⋅x⋅K_{QD}⋅K_{QF}⋅L_D⋅L_{QD}⋅L_{QF}     0.0312031952071892⋅pₓ⋅x⋅K_{QD}
# ──────────────────────────────────────────── - ───────────────────────────────
# ____________________________________________      ____________________________
#              2                        2          ╱                       2
# 6736525267⋅pₓ  - 0.997006736525267⋅p_y  + 1    ╲╱  - 0.997006736525267⋅pₓ  - 0
#
#                          2
# ⋅K_{QF}⋅L_D⋅L_{QD}⋅L_{QF}     0.0312031952071892⋅pₓ⋅x⋅K_{QD}⋅K_{QF}⋅L_D⋅L_{QD}
# ────────────────────────── + ─────────────────────────────────────────────────
# __________________________      ______________________________________________
#                     2          ╱                       2
# .997006736525267⋅p_y  + 1    ╲╱  - 0.997006736525267⋅pₓ  - 0.997006736525267⋅p
#
#        2                                                           2
# ⋅L_{QF}     0.0312031952071892⋅pₓ⋅x⋅K_{QD}⋅K_{QF}⋅L_D⋅L_{QD}⋅L_{QF}
# ──────── + ───────────────────────────────────────────────────────── - ───────
# ________      ______________________________________________________      ____
#   2          ╱                       2                        2          ╱
# _y  + 1    ╲╱  - 0.997006736525267⋅pₓ  - 0.997006736525267⋅p_y  + 1    ╲╱  - 0
#
#
#   0.499251123315027⋅pₓ⋅x⋅K_{QD}⋅L_D⋅L_{QD}                    0.49925112331502
# ────────────────────────────────────────────────── + ─────────────────────────
# __________________________________________________      ______________________
#                    2                        2          ╱
# .997006736525267⋅pₓ  - 0.997006736525267⋅p_y  + 1    ╲╱  - 0.997006736525267⋅p
#
#
# 7⋅pₓ⋅x⋅K_{QD}⋅L_D⋅L_{QD}           pₓ⋅x⋅K_{QD}⋅L_{QD}⋅L_{QF}   pₓ⋅x⋅K_{QD}⋅L_{
# ──────────────────────────────── - ───────────────────────── + ───────────────
# ________________________________               4                           4
#  2                        2
# ₓ  - 0.997006736525267⋅p_y  + 1
#
#                                                2    2       2
# QD}⋅L_{QF}       0.0623129210328292⋅pₓ⋅x⋅K_{QF} ⋅L_D ⋅L_{QF}            0.0624
# ────────── - ──────────────────────────────────────────────────── - ──────────
#                                    2                        2          _______
#              - 0.997006736525267⋅pₓ  - 0.997006736525267⋅p_y  + 1     ╱
#                                                                     ╲╱  - 0.99
#
#                         2                  2
# 063904143784⋅pₓ⋅x⋅K_{QF} ⋅L_D⋅L_{QD}⋅L_{QF}           0.0624063904143784⋅pₓ⋅x⋅
# ─────────────────────────────────────────────── - ────────────────────────────
# _______________________________________________      _________________________
#                 2                        2          ╱                       2
# 7006736525267⋅pₓ  - 0.997006736525267⋅p_y  + 1    ╲╱  - 0.997006736525267⋅pₓ
#
#       2                  2
# K_{QF} ⋅L_D⋅L_{QD}⋅L_{QF}                0.499251123315027⋅pₓ⋅x⋅K_{QF}⋅L_D⋅L_{
# ───────────────────────────── - ──────────────────────────────────────────────
# _____________________________      ___________________________________________
#                        2          ╱                       2
# - 0.997006736525267⋅p_y  + 1    ╲╱  - 0.997006736525267⋅pₓ  - 0.99700673652526
#
#
# QF}                    0.499251123315027⋅pₓ⋅x⋅K_{QF}⋅L_D⋅L_{QF}           pₓ⋅x
# ─────────── + ───────────────────────────────────────────────────────── - ────
# ___________      ______________________________________________________
#      2          ╱                       2                        2
# 7⋅p_y  + 1    ╲╱  - 0.997006736525267⋅pₓ  - 0.997006736525267⋅p_y  + 1
#
#                                                        2             2
# ⋅K_{QF}⋅L_{QD}⋅L_{QF}   pₓ⋅x⋅K_{QF}⋅L_{QD}⋅L_{QF}   p_y ⋅L_{QD}   p_y ⋅L_{QF}
# ───────────────────── + ───────────────────────── - ─────────── - ───────────
#         4                           4                    2             2
#
#
#
#                       2              2    2              2
#   0.0311564605164146⋅x ⋅K_{QD}⋅K_{QF} ⋅L_D ⋅L_{QD}⋅L_{QF}       0.124812780828
# - ──────────────────────────────────────────────────────── - ─────────────────
#                           2                        2            ______________
#     - 0.997006736525267⋅pₓ  - 0.997006736525267⋅p_y  + 1       ╱
#                                                              ╲╱  - 0.997006736
#
#      2                                                           2
# 757⋅x ⋅K_{QD}⋅K_{QF}⋅L_D⋅L_{QD}⋅L_{QF}        0.124812780828757⋅x ⋅K_{QD}⋅K_{Q
# ──────────────────────────────────────── + ───────────────────────────────────
# ________________________________________      ________________________________
#          2                        2          ╱                       2
# 525267⋅pₓ  - 0.997006736525267⋅p_y  + 1    ╲╱  - 0.997006736525267⋅pₓ  - 0.997
#
#                                                2
# F}⋅L_D⋅L_{QD}⋅L_{QF}        0.124812780828757⋅x ⋅K_{QD}⋅K_{QF}⋅L_D⋅L_{QD}⋅L_{Q
# ────────────────────── + ─────────────────────────────────────────────────────
# ______________________      __________________________________________________
#                 2          ╱                       2                        2
# 006736525267⋅p_y  + 1    ╲╱  - 0.997006736525267⋅pₓ  - 0.997006736525267⋅p_y
#
#         2                            2    2
# F}     x ⋅K_{QD}⋅K_{QF}⋅L_{QD}⋅L_{QF}    x ⋅K_{QD}⋅L_{QD}            0.1248127
# ──── - ─────────────────────────────── - ──────────────── + ──────────────────
# ____                  16                        2              _______________
#                                                               ╱
# + 1                                                         ╲╱  - 0.9970067365
#
#           2       2           2            2       2              2    2
# 80828757⋅x ⋅K_{QF} ⋅L_D⋅L_{QF}            x ⋅K_{QF} ⋅L_{QD}⋅L_{QF}    x ⋅K_{QF
# ─────────────────────────────────────── + ───────────────────────── - ────────
# _______________________________________               16                     2
#         2                        2
# 25267⋅pₓ  - 0.997006736525267⋅p_y  + 1
#
#             2                  2                              ________________
# }⋅L_{QF}   y ⋅K_{QD}⋅L_{QD}   y ⋅K_{QF}⋅L_{QF}               ╱
# ──────── + ──────────────── + ──────────────── + 2.003⋅L_D⋅╲╱  - 0.99700673652
#                   2                  2
#
#
#
# ______________________________________
#        2                        2
# 5267⋅pₓ  - 0.997006736525267⋅p_y  + 1  - 0.003⋅L_D

# %%
fodoham2expanded.collect(px**4)
# Out:
#     ⎛                            2              2    2              2
#   4 ⎜                           x ⋅K_{QD}⋅K_{QF} ⋅L_D ⋅L_{QD}⋅L_{QF}
# pₓ ⋅⎜- ───────────────────────────────────────────────────────────────────────
#     ⎜     ⎛    6     4 ⎛         2⎞     2 ⎛       4        2    ⎞      6
#     ⎝  32⋅⎝- pₓ  + pₓ ⋅⎝3 - 3⋅p_y ⎠ + pₓ ⋅⎝- 3⋅p_y  + 6⋅p_y  - 3⎠ - p_y  + 3⋅p
#
#
#                                                     2              2    2
#                                                  3⋅x ⋅K_{QD}⋅K_{QF} ⋅L_D ⋅L_{Q
# ───────────────── - ──────────────────────────────────────────────────────────
#   4        2    ⎞          6     4 ⎛           2⎞     2 ⎛        4          2
# _y  - 3⋅p_y  + 1⎠   - 32⋅pₓ  + pₓ ⋅⎝96 - 96⋅p_y ⎠ + pₓ ⋅⎝- 96⋅p_y  + 192⋅p_y
#
#
#          2                                                           2
# D}⋅L_{QF}                                           K_{QD}⋅K_{QF}⋅L_D ⋅L_{QD}⋅
# ──────────────────────────────────────── + ───────────────────────────────────
#     ⎞         6         4         2             4     2 ⎛      2     ⎞
# - 96⎠ - 32⋅p_y  + 96⋅p_y  - 96⋅p_y  + 32   32⋅pₓ  + pₓ ⋅⎝64⋅p_y  - 64⎠ + 32⋅p_
#
#
#       2          ⎞
# L_{QF}           ⎟
# ─────────────────⎟ - ─────────────────────────────────────────────────────────
#  4         2     ⎟      ⎛       __________________       ⎛          __________
# y  - 64⋅p_y  + 32⎠      ⎜  4   ╱     2      2          2 ⎜     2   ╱     2
#                      32⋅⎝pₓ ⋅╲╱  - pₓ  - p_y  + 1  + pₓ ⋅⎝2⋅p_y ⋅╲╱  - pₓ  - p
#
#                3  3              2                  2
#            3⋅pₓ ⋅x ⋅K_{QD}⋅K_{QF} ⋅L_D⋅L_{QD}⋅L_{QF}
# ──────────────────────────────────────────────────────────────────────────────
# ________        __________________⎞           __________________             _
#   2            ╱     2      2     ⎟      4   ╱     2      2             2   ╱
# _y  + 1  - 2⋅╲╱  - pₓ  - p_y  + 1 ⎠ + p_y ⋅╲╱  - pₓ  - p_y  + 1  - 2⋅p_y ⋅╲╱
#
#                                                       3                    2
#                                                     pₓ ⋅x⋅K_{QD}⋅K_{QF}⋅L_D ⋅L
# ────────────────────────────────────────── - ─────────────────────────────────
# _________________      __________________⎞        4     2 ⎛      2     ⎞
#     2      2          ╱     2      2     ⎟   16⋅pₓ  + pₓ ⋅⎝32⋅p_y  - 32⎠ + 16⋅
# - pₓ  - p_y  + 1  + ╲╱  - pₓ  - p_y  + 1 ⎠
#
#                                3                    2
# _{QD}⋅L_{QF}                 pₓ ⋅x⋅K_{QD}⋅K_{QF}⋅L_D ⋅L_{QD}⋅L_{QF}
# ─────────────────── - ──────────────────────────────────────────────────── + ─
#    4         2             4     2 ⎛      2     ⎞         4         2
# p_y  - 32⋅p_y  + 16   16⋅pₓ  + pₓ ⋅⎝32⋅p_y  - 32⎠ + 16⋅p_y  - 32⋅p_y  + 16   1
#
#
#         3                    2                                 3
#       pₓ ⋅x⋅K_{QD}⋅K_{QF}⋅L_D ⋅L_{QD}⋅L_{QF}                 pₓ ⋅x⋅K_{QD}⋅K_{Q
# ─────────────────────────────────────────────────── + ────────────────────────
#     4     2 ⎛      2     ⎞         4         2             4     2 ⎛      2
# 6⋅pₓ  + pₓ ⋅⎝32⋅p_y  - 32⎠ + 16⋅p_y  - 32⋅p_y  + 16   16⋅pₓ  + pₓ ⋅⎝32⋅p_y  -
#
#
#       2                                                  3
# F}⋅L_D ⋅L_{QD}⋅L_{QF}                                  pₓ ⋅x⋅K_{QD}⋅K_{QF}⋅L_D
# ──────────────────────────── - ───────────────────────────────────────────────
#   ⎞         4         2           ⎛         __________________           _____
# 32⎠ + 16⋅p_y  - 32⋅p_y  + 16      ⎜    2   ╱     2      2           2   ╱
#                                32⋅⎝- pₓ ⋅╲╱  - pₓ  - p_y  + 1  - p_y ⋅╲╱  - pₓ
#
#               2                                                    3
# ⋅L_{QD}⋅L_{QF}                                                   pₓ ⋅x⋅K_{QD}⋅
# ────────────────────────────────────── + ─────────────────────────────────────
# _____________      __________________⎞      ⎛         __________________
# 2      2          ╱     2      2     ⎟      ⎜    2   ╱     2      2
#   - p_y  + 1  + ╲╱  - pₓ  - p_y  + 1 ⎠   32⋅⎝- pₓ ⋅╲╱  - pₓ  - p_y  + 1  - p_y
#
#                         2                                                    3
# K_{QF}⋅L_D⋅L_{QD}⋅L_{QF}                                                   pₓ
# ──────────────────────────────────────────────── + ───────────────────────────
#      __________________      __________________⎞      ⎛         ______________
# 2   ╱     2      2          ╱     2      2     ⎟      ⎜    2   ╱     2      2
#  ⋅╲╱  - pₓ  - p_y  + 1  + ╲╱  - pₓ  - p_y  + 1 ⎠   32⋅⎝- pₓ ⋅╲╱  - pₓ  - p_y
#
#                                   2                                         3
# ⋅x⋅K_{QD}⋅K_{QF}⋅L_D⋅L_{QD}⋅L_{QF}                                        pₓ ⋅
# ────────────────────────────────────────────────────────── - ─────────────────
# ____           __________________      __________________⎞        4     2 ⎛
#           2   ╱     2      2          ╱     2      2     ⎟   16⋅pₓ  + pₓ ⋅⎝32⋅
# + 1  - p_y ⋅╲╱  - pₓ  - p_y  + 1  + ╲╱  - pₓ  - p_y  + 1 ⎠
#
#         2    2       2                                             3         2
# x⋅K_{QF} ⋅L_D ⋅L_{QF}                                            pₓ ⋅x⋅K_{QF}
# ─────────────────────────────────── + ────────────────────────────────────────
#    2     ⎞         4         2           ⎛         __________________
# p_y  - 32⎠ + 16⋅p_y  - 32⋅p_y  + 16      ⎜    2   ╱     2      2           2
#                                       32⋅⎝- pₓ ⋅╲╱  - pₓ  - p_y  + 1  - p_y ⋅╲
#
#                   2                                                          3
# ⋅L_D⋅L_{QD}⋅L_{QF}                                                         pₓ
# ───────────────────────────────────────────── + ──────────────────────────────
#   __________________      __________________⎞      ⎛         _________________
#  ╱     2      2          ╱     2      2     ⎟      ⎜    2   ╱     2      2
# ╱  - pₓ  - p_y  + 1  + ╲╱  - pₓ  - p_y  + 1 ⎠   32⋅⎝- pₓ ⋅╲╱  - pₓ  - p_y  + 1
#
#          2                  2                                 ⎛           2
# ⋅x⋅K_{QF} ⋅L_D⋅L_{QD}⋅L_{QF}                                2 ⎜        3⋅x ⋅K_
# ─────────────────────────────────────────────────────── + pₓ ⋅⎜- ─────────────
# _           __________________      __________________⎞       ⎜       4     2
#        2   ╱     2      2          ╱     2      2     ⎟       ⎜  32⋅pₓ  + pₓ ⋅
#   - p_y ⋅╲╱  - pₓ  - p_y  + 1  + ╲╱  - pₓ  - p_y  + 1 ⎠       ⎝
#
#            2    2              2                  2              2    2
# {QD}⋅K_{QF} ⋅L_D ⋅L_{QD}⋅L_{QF}                  x ⋅K_{QD}⋅K_{QF} ⋅L_D ⋅L_{QD}
# ─────────────────────────────────────── - ────────────────────────────────────
# ⎛      2     ⎞         4         2             4     2 ⎛      2     ⎞
# ⎝64⋅p_y  - 64⎠ + 32⋅p_y  - 64⋅p_y  + 32   16⋅pₓ  + pₓ ⋅⎝32⋅p_y  - 32⎠ + 16⋅p_y
#
#
#        2                                     2
# ⋅L_{QF}                                     x ⋅K_{QD}⋅K_{QF}⋅L_D⋅L_{QD}⋅L_{QF}
# ──────────────── - ───────────────────────────────────────────────────────────
# 4         2          ⎛         __________________           __________________
#   - 32⋅p_y  + 16     ⎜    2   ╱     2      2           2   ╱     2      2
#                    8⋅⎝- pₓ ⋅╲╱  - pₓ  - p_y  + 1  - p_y ⋅╲╱  - pₓ  - p_y  + 1
#
#                                                             2       2
#                                                            x ⋅K_{QF} ⋅L_D⋅L_{Q
# ───────────────────────── - ──────────────────────────────────────────────────
#       __________________⎞     ⎛         __________________           _________
#      ╱     2      2     ⎟     ⎜    2   ╱     2      2           2   ╱     2
#  + ╲╱  - pₓ  - p_y  + 1 ⎠   8⋅⎝- pₓ ⋅╲╱  - pₓ  - p_y  + 1  - p_y ⋅╲╱  - pₓ  -
#
#   2                                                   2              2
# F}                                   K_{QD}⋅K_{QF}⋅L_D ⋅L_{QD}⋅L_{QF}     K_{Q
# ────────────────────────────────── + ───────────────────────────────── + ─────
# _________      __________________⎞            ⎛    2      2    ⎞           ⎛
#    2          ╱     2      2     ⎟         32⋅⎝- pₓ  - p_y  + 1⎠         4⋅⎝-
# p_y  + 1  + ╲╱  - pₓ  - p_y  + 1 ⎠
#
#       2                                                          2
# D}⋅L_D ⋅L_{QD}    K_{QD}⋅L_D⋅L_{QD}⋅L_{QF}   K_{QD}⋅L_{QD}⋅L_{QF}     K_{QF}⋅L
# ─────────────── - ──────────────────────── + ───────────────────── - ─────────
#   2      2    ⎞        __________________              16              ⎛    2
# pₓ  - p_y  + 1⎠       ╱     2      2                                 8⋅⎝- pₓ
#                   8⋅╲╱  - pₓ  - p_y  + 1
#
#   2                                                          2
# _D ⋅L_{QF}    K_{QF}⋅L_D⋅L_{QD}⋅L_{QF}      K_{QF}⋅L_D⋅L_{QF}      K_{QF}⋅L_{Q
# ─────────── + ──────────────────────── + ─────────────────────── - ───────────
#      2    ⎞        __________________         __________________             1
# - p_y  + 1⎠       ╱     2      2             ╱     2      2
#               4⋅╲╱  - pₓ  - p_y  + 1     8⋅╲╱  - pₓ  - p_y  + 1
#
#          2                  ⎞                               3              2
# D}⋅L_{QF}    L_{QD}   L_{QF}⎟                         3⋅pₓ⋅x ⋅K_{QD}⋅K_{QF} ⋅L
# ────────── - ────── - ──────⎟ - ──────────────────────────────────────────────
# 6              2        2   ⎟      ⎛         __________________           ____
#                             ⎟      ⎜    2   ╱     2      2           2   ╱
#                             ⎠   32⋅⎝- pₓ ⋅╲╱  - pₓ  - p_y  + 1  - p_y ⋅╲╱  - p
#
#                 2                                               2
# _D⋅L_{QD}⋅L_{QF}                          pₓ⋅x⋅K_{QD}⋅K_{QF}⋅L_D ⋅L_{QD}⋅L_{QF
# ─────────────────────────────────────── - ────────────────────────────────────
# ______________      __________________⎞              ⎛    2      2    ⎞
#  2      2          ╱     2      2     ⎟           16⋅⎝- pₓ  - p_y  + 1⎠
# ₓ  - p_y  + 1  + ╲╱  - pₓ  - p_y  + 1 ⎠
#
#                           2                                       2
# }   pₓ⋅x⋅K_{QD}⋅K_{QF}⋅L_D ⋅L_{QD}⋅L_{QF}   pₓ⋅x⋅K_{QD}⋅K_{QF}⋅L_D ⋅L_{QD}⋅L_{
# ─ - ───────────────────────────────────── + ──────────────────────────────────
#                ⎛    2      2    ⎞                      ⎛    2      2    ⎞
#             16⋅⎝- pₓ  - p_y  + 1⎠                   16⋅⎝- pₓ  - p_y  + 1⎠
#
#
#                             2
# QF}   pₓ⋅x⋅K_{QD}⋅K_{QF}⋅L_D ⋅L_{QD}⋅L_{QF}   pₓ⋅x⋅K_{QD}⋅K_{QF}⋅L_D⋅L_{QD}⋅L_
# ─── + ───────────────────────────────────── - ────────────────────────────────
#                  ⎛    2      2    ⎞                        __________________
#               16⋅⎝- pₓ  - p_y  + 1⎠                       ╱     2      2
#                                                      32⋅╲╱  - pₓ  - p_y  + 1
#
#     2                                       2
# {QF}    pₓ⋅x⋅K_{QD}⋅K_{QF}⋅L_D⋅L_{QD}⋅L_{QF}    pₓ⋅x⋅K_{QD}⋅K_{QF}⋅L_D⋅L_{QD}⋅
# ───── - ───────────────────────────────────── + ──────────────────────────────
#                      __________________                      _________________
#                     ╱     2      2                          ╱     2      2
#                32⋅╲╱  - pₓ  - p_y  + 1                 32⋅╲╱  - pₓ  - p_y  + 1
#
#       2                                       2
# L_{QF}    pₓ⋅x⋅K_{QD}⋅K_{QF}⋅L_D⋅L_{QD}⋅L_{QF}     pₓ⋅x⋅K_{QD}⋅L_D⋅L_{QD}    p
# ─────── + ───────────────────────────────────── - ─────────────────────── + ──
# _                      __________________              __________________
#                       ╱     2      2                  ╱     2      2
#                  32⋅╲╱  - pₓ  - p_y  + 1          2⋅╲╱  - pₓ  - p_y  + 1    2⋅
#
#
# ₓ⋅x⋅K_{QD}⋅L_D⋅L_{QD}   pₓ⋅x⋅K_{QD}⋅L_{QD}⋅L_{QF}   pₓ⋅x⋅K_{QD}⋅L_{QD}⋅L_{QF}
# ───────────────────── - ───────────────────────── + ─────────────────────────
#    __________________               4                           4
#   ╱     2      2
# ╲╱  - pₓ  - p_y  + 1
#
#              2    2       2              2                  2              2
#   pₓ⋅x⋅K_{QF} ⋅L_D ⋅L_{QF}    pₓ⋅x⋅K_{QF} ⋅L_D⋅L_{QD}⋅L_{QF}    pₓ⋅x⋅K_{QF} ⋅L
# - ───────────────────────── + ─────────────────────────────── + ──────────────
#        ⎛    2      2    ⎞               __________________                ____
#     16⋅⎝- pₓ  - p_y  + 1⎠              ╱     2      2                    ╱
#                                   16⋅╲╱  - pₓ  - p_y  + 1           16⋅╲╱  - p
#
#                 2
# _D⋅L_{QD}⋅L_{QF}     pₓ⋅x⋅K_{QF}⋅L_D⋅L_{QF}    pₓ⋅x⋅K_{QF}⋅L_D⋅L_{QF}   pₓ⋅x⋅K
# ───────────────── - ─────────────────────── + ─────────────────────── - ──────
# ______________           __________________        __________________
#  2      2               ╱     2      2            ╱     2      2
# ₓ  - p_y  + 1       2⋅╲╱  - pₓ  - p_y  + 1    2⋅╲╱  - pₓ  - p_y  + 1
#
#                                                      2             2
# _{QF}⋅L_{QD}⋅L_{QF}   pₓ⋅x⋅K_{QF}⋅L_{QD}⋅L_{QF}   p_y ⋅L_{QD}   p_y ⋅L_{QF}
# ─────────────────── + ───────────────────────── - ─────────── - ─────────── -
#       4                           4                    2             2
#
#
#
#  2              2    2              2    2
# x ⋅K_{QD}⋅K_{QF} ⋅L_D ⋅L_{QD}⋅L_{QF}    x ⋅K_{QD}⋅K_{QF}⋅L_D⋅L_{QD}⋅L_{QF}   x
# ───────────────────────────────────── - ────────────────────────────────── - ─
#            ⎛    2      2    ⎞                     __________________
#         32⋅⎝- pₓ  - p_y  + 1⎠                    ╱     2      2
#                                              8⋅╲╱  - pₓ  - p_y  + 1
#
# 2                                    2                                    2
#  ⋅K_{QD}⋅K_{QF}⋅L_D⋅L_{QD}⋅L_{QF}   x ⋅K_{QD}⋅K_{QF}⋅L_D⋅L_{QD}⋅L_{QF}   x ⋅K_
# ───────────────────────────────── + ────────────────────────────────── - ─────
#          __________________                   __________________
#         ╱     2      2                       ╱     2      2
#     8⋅╲╱  - pₓ  - p_y  + 1               8⋅╲╱  - pₓ  - p_y  + 1
#
#                          2    2                   2       2           2    2
# {QD}⋅K_{QF}⋅L_{QD}⋅L_{QF}    x ⋅K_{QD}⋅L_{QD}    x ⋅K_{QF} ⋅L_D⋅L_{QF}    x ⋅K
# ────────────────────────── - ──────────────── - ─────────────────────── + ────
#           16                        2                __________________
#                                                     ╱     2      2
#                                                 8⋅╲╱  - pₓ  - p_y  + 1
#
#      2              2    2                  2                  2
# _{QF} ⋅L_{QD}⋅L_{QF}    x ⋅K_{QF}⋅L_{QF}   y ⋅K_{QD}⋅L_{QD}   y ⋅K_{QF}⋅L_{QF}
# ───────────────────── - ──────────────── + ──────────────── + ────────────────
#         16                     2                  2                  2
#
#
#
#             __________________
#            ╱     2      2
#  - 2⋅L_D⋅╲╱  - pₓ  - p_y  + 1

# %%
fodoham2expandednum = fodoham2expanded.subs(rep)
fodoham2expandednum
# Out:
#
#
# ──────────────────────────────────────────────────────────────────────────────
#                       6                     4    2                      4
# - 0.991047061635966⋅pₓ  - 2.9731411849079⋅pₓ ⋅p_y  + 2.98206729803029⋅pₓ  - 2.
#
#
#                                            4  2
#                       0.0148934605282245⋅pₓ ⋅x
# ──────────────────────────────────────────────────────────────────────────────
#                 2    4                      2    2                     2
# 9731411849079⋅pₓ ⋅p_y  + 5.96413459606058⋅pₓ ⋅p_y  - 2.9910202095758⋅pₓ  - 0.9
#
#
#
#
# ────────────────────────────────────────────────────────────────────── - ─────
#                   6                       4                      2
# 91047061635966⋅p_y  + 2.98206729803029⋅p_y  - 2.9910202095758⋅p_y  + 1   0.994
#
#
#                                                                     4
#                                               0.00762151756127315⋅pₓ
# ──────────────────────────────────────────────────────────────────────────────
#                4                      2    2                      2
# 022432676763⋅pₓ  + 1.98804486535353⋅pₓ ⋅p_y  - 1.99401347305053⋅pₓ  + 0.994022
#
#
#
#
# ────────────────────────────────────────── - ─────────────────────────────────
#              4                       2                                ________
# 432676763⋅p_y  - 1.99401347305053⋅p_y  + 1                       4   ╱
#                                              0.994022432676763⋅pₓ ⋅╲╱  - 0.997
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
# ______________________________________________
#                2                        2                           2    2   ╱
# 006736525267⋅pₓ  - 0.997006736525267⋅p_y  + 1  + 1.98804486535353⋅pₓ ⋅p_y ⋅╲╱
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
# ______________________________________________________
#                        2                        2                           2
#  - 0.997006736525267⋅pₓ  - 0.997006736525267⋅p_y  + 1  - 1.99401347305053⋅pₓ ⋅
#
#                                                         3  3
#                                   0.00312438222015435⋅pₓ ⋅x
# ──────────────────────────────────────────────────────────────────────────────
#    ______________________________________________________
#   ╱                       2                        2
# ╲╱  - 0.997006736525267⋅pₓ  - 0.997006736525267⋅p_y  + 1  + 0.994022432676763⋅
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#         ______________________________________________________
#    4   ╱                       2                        2
# p_y ⋅╲╱  - 0.997006736525267⋅pₓ  - 0.997006736525267⋅p_y  + 1  - 1.99401347305
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#             ______________________________________________________      ______
#        2   ╱                       2                        2          ╱
# 053⋅p_y ⋅╲╱  - 0.997006736525267⋅pₓ  - 0.997006736525267⋅p_y  + 1  + ╲╱  - 0.9
#
#
#
# ──────────────────────────────────────────────── - ───────────────────────────
# ________________________________________________                       4
#                  2                        2        0.994022432676763⋅pₓ  + 1.9
# 97006736525267⋅pₓ  - 0.997006736525267⋅p_y  + 1
#
#                                              3
#                         0.0223670099590208⋅pₓ ⋅x
# ──────────────────────────────────────────────────────────────────────────────
#                 2    2                      2                        4
# 8804486535353⋅pₓ ⋅p_y  - 1.99401347305053⋅pₓ  + 0.994022432676763⋅p_y  - 1.994
#
#
#
#
# ──────────────────── - ───────────────────────────────────────────────────────
#                2                                  ____________________________
# 01347305053⋅p_y  + 1                         2   ╱                       2
#                        - 0.997006736525267⋅pₓ ⋅╲╱  - 0.997006736525267⋅pₓ  - 0
#
#                                                                   3
#                                              0.0020473745451724⋅pₓ ⋅x
# ──────────────────────────────────────────────────────────────────────────────
# __________________________                             _______________________
#                     2                             2   ╱
# .997006736525267⋅p_y  + 1  - 0.997006736525267⋅p_y ⋅╲╱  - 0.997006736525267⋅pₓ
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
# _______________________________      _________________________________________
# 2                        2          ╱                       2
#   - 0.997006736525267⋅p_y  + 1  + ╲╱  - 0.997006736525267⋅pₓ  - 0.997006736525
#
#
#                                                                   0.0186727180
# ───────────── + ──────────────────────────────────────────────────────────────
# _____________                       4                      2    2
#        2        0.994022432676763⋅pₓ  + 1.98804486535353⋅pₓ ⋅p_y  - 1.99401347
# 267⋅p_y  + 1
#
#          2  2
# 251192⋅pₓ ⋅x
# ─────────────────────────────────────────────────────────────── - ────────────
#          2                        4                       2
# 305053⋅pₓ  + 0.994022432676763⋅p_y  - 1.99401347305053⋅p_y  + 1
#                                                                   - 0.99700673
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#                ______________________________________________________
#           2   ╱                       2                        2
# 6525267⋅pₓ ⋅╲╱  - 0.997006736525267⋅pₓ  - 0.997006736525267⋅p_y  + 1  - 0.9970
#
#                               2  2
#          0.0124209317577685⋅pₓ ⋅x
# ──────────────────────────────────────────────────────────────────────────────
#                     ______________________________________________________
#                2   ╱                       2                        2
# 06736525267⋅p_y ⋅╲╱  - 0.997006736525267⋅pₓ  - 0.997006736525267⋅p_y  + 1  + ╲
#
#
#                                                                              2
# ──────────────────────────────────────────────────────── - 0.5098339262053⋅pₓ
#   ______________________________________________________
#  ╱                       2                        2
# ╱  - 0.997006736525267⋅pₓ  - 0.997006736525267⋅p_y  + 1
#
#                                       2
#                    1.34243780923897⋅pₓ                                      0.
#  - ──────────────────────────────────────────────────── - ────────────────────
#                          2                        2          _________________
#    - 0.997006736525267⋅pₓ  - 0.997006736525267⋅p_y  + 1     ╱
#                                                           ╲╱  - 0.997006736525
#
#                   2
# 176703124581777⋅pₓ
# ───────────────────────────────────── - ──────────────────────────────────────
# _____________________________________                              ___________
#       2                        2                              2   ╱
# 267⋅pₓ  - 0.997006736525267⋅p_y  + 1    - 0.997006736525267⋅pₓ ⋅╲╱  - 0.997006
#
#
#                                                              0.003133762396674
# ──────────────────────────────────────────────────────────────────────────────
# ___________________________________________                             ______
#             2                        2                             2   ╱
# 736525267⋅pₓ  - 0.997006736525267⋅p_y  + 1  - 0.997006736525267⋅p_y ⋅╲╱  - 0.9
#
#        3
# 81⋅pₓ⋅x
# ──────────────────────────────────────────────────────────────────────────────
# ________________________________________________      ________________________
#                  2                        2          ╱                       2
# 97006736525267⋅pₓ  - 0.997006736525267⋅p_y  + 1  + ╲╱  - 0.997006736525267⋅pₓ
#
#
#                                                0.0224341613146703⋅pₓ⋅x
# ────────────────────────────── - ─────────────────────────────────────────────
# ______________________________                         2
#                         2        - 0.997006736525267⋅pₓ  - 0.997006736525267⋅p
#  - 0.997006736525267⋅p_y  + 1
#
#
#                            0.00838346531927778⋅pₓ⋅x
# ─────── - ───────────────────────────────────────────────────────── - 0.505⋅p_
#   2          ______________________________________________________
# _y  + 1     ╱                       2                        2
#           ╲╱  - 0.997006736525267⋅pₓ  - 0.997006736525267⋅p_y  + 1
#
#                                                                 2
#  2                      2                  0.00374575563856203⋅x
# y  + 0.085545223840597⋅x  + ──────────────────────────────────────────────────
#                                                   2                        2
#                             - 0.997006736525267⋅pₓ  - 0.997006736525267⋅p_y  +
#
#
#                                            2
#                        0.0124582225001383⋅x                                 2
# ── - ───────────────────────────────────────────────────────── - 0.0831766⋅y
#         ______________________________________________________
#  1     ╱                       2                        2
#      ╲╱  - 0.997006736525267⋅pₓ  - 0.997006736525267⋅p_y  + 1
#
#                ______________________________________________________
#               ╱                       2                        2
# + 7.1717415⋅╲╱  - 0.997006736525267⋅pₓ  - 0.997006736525267⋅p_y  + 1  - 0.0107
#
#
#
#
#
#
# 415

# %%
fodoham2expandednum.collect(px**4)
# Out:
#     ⎛
#   4 ⎜                                                                  0.00375
# pₓ ⋅⎜─────────────────────────────────────────────────────────────────────────
#     ⎜    6     4 ⎛                  2⎞     2 ⎛       4                2
#     ⎝- pₓ  + pₓ ⋅⎝3.00900675 - 3⋅p_y ⎠ + pₓ ⋅⎝- 3⋅p_y  + 6.0180135⋅p_y  - 3.01
#
#
#              2
# 70013334279⋅x
# ──────────────────────────────────────────────────────────────────────────────
#             ⎞      6                 4                       2
# 804054051519⎠ - p_y  + 3.00900675⋅p_y  - 3.01804054051519⋅p_y  + 1.00903381757
#
#
#
#                                                                             0.
# ─── + ────────────────────────────────────────────────────────────────────────
#              6     4 ⎛                  2⎞     2 ⎛        4                 2
# 598   - 32⋅pₓ  + pₓ ⋅⎝96.288216 - 96⋅p_y ⎠ + pₓ ⋅⎝- 96⋅p_y  + 192.576432⋅p_y
#
#
#                  2
# 360672128009078⋅x
# ──────────────────────────────────────────────────────────────────────────────
#                  ⎞         6                4                      2
# - 96.577297296486⎠ - 32⋅p_y  + 96.288216⋅p_y  - 96.577297296486⋅p_y  + 32.2890
#
#
#
#                                            0.245355189121822
# ───────── - ──────────────────────────────────────────────────────────────────
#                  4     2 ⎛      2            ⎞         4                2
# 821624315   32⋅pₓ  + pₓ ⋅⎝64⋅p_y  - 64.192144⎠ + 32⋅p_y  - 64.192144⋅p_y  + 32
#
#
#              ⎞
#              ⎟
# ─────────────⎟ - ─────────────────────────────────────────────────────────────
#              ⎟                 _______________________________________________
# .192432432162⎠            4   ╱                       2
#                  1.0015⋅pₓ ⋅╲╱  - 0.997006736525267⋅pₓ  - 0.997006736525267⋅p_
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
# _______       ⎛              _________________________________________________
#  2          2 ⎜         2   ╱                       2                        2
# y  + 1  + pₓ ⋅⎝2.003⋅p_y ⋅╲╱  - 0.997006736525267⋅pₓ  - 0.997006736525267⋅p_y
#
#
#                                                                         0.0031
# ──────────────────────────────────────────────────────────────────────────────
# _____                    _____________________________________________________
#                         ╱                       2                        2
#  + 1  - 2.00901350675⋅╲╱  - 0.997006736525267⋅pₓ  - 0.997006736525267⋅p_y  + 1
#
#                 3  3
# 4788549093247⋅pₓ ⋅x
# ──────────────────────────────────────────────────────────────────────────────
# _⎞                  ______________________________________________________
#  ⎟             4   ╱                       2                        2
#  ⎠ + 1.0015⋅p_y ⋅╲╱  - 0.997006736525267⋅pₓ  - 0.997006736525267⋅p_y  + 1  - 2
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#                      ______________________________________________________
#                 2   ╱                       2                        2
# .00901350675⋅p_y ⋅╲╱  - 0.997006736525267⋅pₓ  - 0.997006736525267⋅p_y  + 1  +
#
#
#
# ────────────────────────────────────────────────────────────────────────── - ─
#                     ______________________________________________________
#                    ╱                       2                        2        1
# 1.00752253377532⋅╲╱  - 0.997006736525267⋅pₓ  - 0.997006736525267⋅p_y  + 1
#
#                                                3
#                            0.360024228407636⋅pₓ ⋅x
# ──────────────────────────────────────────────────────────────────────────────
#     4     2 ⎛      2            ⎞         4                2
# 6⋅pₓ  + pₓ ⋅⎝32⋅p_y  - 32.096072⎠ + 16⋅p_y  - 32.096072⋅p_y  + 16.096216216081
#
#
#
#
#  - ───────────────────────────────────────────────────────────────────────────
#                    ______________________________________________________
#               2   ╱                       2                        2
#    - 1.0015⋅pₓ ⋅╲╱  - 0.997006736525267⋅pₓ  - 0.997006736525267⋅p_y  + 1  - 1.
#
#                                            3
#                      0.00205660155731375⋅pₓ ⋅x
# ──────────────────────────────────────────────────────────────────────────────
#              ______________________________________________________
#         2   ╱                       2                        2
# 0015⋅p_y ⋅╲╱  - 0.997006736525267⋅pₓ  - 0.997006736525267⋅p_y  + 1  + 1.004506
#
#                                                                        ⎛
#                                                                      2 ⎜
# ──────────────────────────────────────────────────────────────── + pₓ ⋅⎜──────
#           ______________________________________________________       ⎜     4
#          ╱                       2                        2            ⎜32⋅pₓ
# 753375⋅╲╱  - 0.997006736525267⋅pₓ  - 0.997006736525267⋅p_y  + 1        ⎝
#
#                                            2
#                         0.360672128009078⋅x
# ───────────────────────────────────────────────────────────────────────── + ──
#      2 ⎛      2            ⎞         4                2
#  + pₓ ⋅⎝64⋅p_y  - 64.192144⎠ + 32⋅p_y  - 64.192144⋅p_y  + 32.192432432162   16
#
#
#                                                2
#                             0.120224042669693⋅x
# ─────────────────────────────────────────────────────────────────────────────
#    4     2 ⎛      2            ⎞         4                2
# ⋅pₓ  + pₓ ⋅⎝32⋅p_y  - 32.096072⎠ + 16⋅p_y  - 32.096072⋅p_y  + 16.096216216081
#
#
#
#
# - ────────────────────────────────────────────────────────────────────────────
#                   ______________________________________________________
#              2   ╱                       2                        2
#   - 1.0015⋅pₓ ⋅╲╱  - 0.997006736525267⋅pₓ  - 0.997006736525267⋅p_y  + 1  - 1.0
#
#                                           2
#                       0.0124769098338885⋅x
# ──────────────────────────────────────────────────────────────────────────────
#             ______________________________________________________
#        2   ╱                       2                        2
# 015⋅p_y ⋅╲╱  - 0.997006736525267⋅pₓ  - 0.997006736525267⋅p_y  + 1  + 1.0045067
#
#
#
# ─────────────────────────────────────────────────────────────── - 0.5098339262
#          ______________________________________________________
#         ╱                       2                        2
# 53375⋅╲╱  - 0.997006736525267⋅pₓ  - 0.997006736525267⋅p_y  + 1
#
#
#                           0.176703124581777                            1.34646
# 053 - ───────────────────────────────────────────────────────── - ────────────
#          ______________________________________________________       2      2
#         ╱                       2                        2        - pₓ  - p_y
#       ╲╱  - 0.997006736525267⋅pₓ  - 0.997006736525267⋅p_y  + 1
#
#              ⎞
# 814315176    ⎟
# ─────────────⎟ - ─────────────────────────────────────────────────────────────
#              ⎟                   _____________________________________________
#  + 1.00300225⎟              2   ╱                       2
#              ⎠   - 1.0015⋅pₓ ⋅╲╱  - 0.997006736525267⋅pₓ  - 0.997006736525267⋅
#
#                                                            3
#                                    0.00314788549093247⋅pₓ⋅x
# ──────────────────────────────────────────────────────────────────────────────
# _________                  ___________________________________________________
#    2                  2   ╱                       2                        2
# p_y  + 1  - 1.0015⋅p_y ⋅╲╱  - 0.997006736525267⋅pₓ  - 0.997006736525267⋅p_y  +
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
# ___                     ______________________________________________________
#                        ╱                       2                        2
#  1  + 1.004506753375⋅╲╱  - 0.997006736525267⋅pₓ  - 0.997006736525267⋅p_y  + 1
#
#
#                     0.00838346531927778⋅pₓ⋅x                    0.022501514275
#  - ───────────────────────────────────────────────────────── - ───────────────
#       ______________________________________________________       2      2
#      ╱                       2                        2        - pₓ  - p_y  +
#    ╲╱  - 0.997006736525267⋅pₓ  - 0.997006736525267⋅p_y  + 1
#
#
# 4773⋅pₓ⋅x             2                      2                     0.012458222
# ────────── - 0.505⋅p_y  + 0.085545223840597⋅x  - ─────────────────────────────
#                                                     __________________________
# 1.00300225                                         ╱                       2
#                                                  ╲╱  - 0.997006736525267⋅pₓ  -
#
#          2                                           2
# 5001383⋅x                        0.0037570013334279⋅x                 2
# ──────────────────────────── + ───────────────────────── - 0.0831766⋅y  + 7.17
# ____________________________       2      2
#                       2        - pₓ  - p_y  + 1.00300225
#  0.997006736525267⋅p_y  + 1
#
#          ______________________________________________________
#         ╱                       2                        2
# 17415⋅╲╱  - 0.997006736525267⋅pₓ  - 0.997006736525267⋅p_y  + 1  - 0.0107415

# %%
fodoham2num = lambdify((x,px),fodoham2expandednum.subs([y,py],[0,0]),'numpy')

# %%
fodoham2num = lambdify((x,px,y,py),fodoham2expandednum,'numpy')

# %%
def fodoxplane(x,px):
    return fodoham2num(x,px,0,0)

# %%
fodoxplane(0,0)
# Out:
# 7.1610000000000005

# %%
multi_countour_plot(
    [fodoxplane], 
    titlelist=["$1^e$ order","$2^e$ order","$3^e$ order","$4^e$ order"],
    xlabels=[r"$x$"]*4,
    ylabels=[r"$p_x$"]*4,
    xrange=3,
    prange=.8,
)
# Out:
# <img src="data:image/png;base64,..." width="1200">

# %%
simplify(fodoham2expanded)
# Out:
# ---------------------------------------------------------------
# KeyError                      Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/sympy/core/assumptions.py in getit(self)
#     453         try:
# --> 454             return self._assumptions[fact]
#     455         except KeyError:
#
# KeyError: 'positive'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                      Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/sympy/core/assumptions.py in getit(self)
#     453         try:
# --> 454             return self._assumptions[fact]
#     455         except KeyError:
#
# KeyError: 'extended_positive'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                      Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/sympy/core/assumptions.py in getit(self)
#     453         try:
# --> 454             return self._assumptions[fact]
#     455         except KeyError:
#
# KeyError: 'extended_real'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                     Traceback (most recent call last)
# <ipython-input-112-bf61d206a244> in <module>
# ----> 1 simplify(fodoham2expanded)
#
# ~/.local/lib/python3.6/site-packages/sympy/simplify/simplify.py in simplify(expr, ratio, measure, rational, inverse, doit, **kwargs)
#     682         expr = quantity_simplify(expr)
#     683
# --> 684     short = shorter(powsimp(expr, combine='exp', deep=True), powsimp(expr), expr)
#     685     short = shorter(short, cancel(short))
#     686     short = shorter(short, factor_terms(short), expand_power_exp(expand_mul(short)))
#
# ~/.local/lib/python3.6/site-packages/sympy/simplify/powsimp.py in powsimp(expr, deep, combine, force, measure)
#     116
#     117     if deep or expr.is_Add or expr.is_Mul and _y not in expr.args:
# --> 118         expr = expr.func(*[recurse(w) for w in expr.args])
#     119
#     120     if expr.is_Pow:
#
# ~/.local/lib/python3.6/site-packages/sympy/simplify/powsimp.py in <listcomp>(.0)
#     116
#     117     if deep or expr.is_Add or expr.is_Mul and _y not in expr.args:
# --> 118         expr = expr.func(*[recurse(w) for w in expr.args])
#     119
#     120     if expr.is_Pow:
#
# ~/.local/lib/python3.6/site-packages/sympy/simplify/powsimp.py in recurse(arg, **kwargs)
#     107         _force = kwargs.get('force', force)
#     108         _measure = kwargs.get('measure', measure)
# --> 109         return powsimp(arg, _deep, _combine, _force, _measure)
#     110
#     111     expr = sympify(expr)
#
# ~/.local/lib/python3.6/site-packages/sympy/simplify/powsimp.py in powsimp(expr, deep, combine, force, measure)
#     116
#     117     if deep or expr.is_Add or expr.is_Mul and _y not in expr.args:
# --> 118         expr = expr.func(*[recurse(w) for w in expr.args])
#     119
#     120     if expr.is_Pow:
#
# ~/.local/lib/python3.6/site-packages/sympy/simplify/powsimp.py in <listcomp>(.0)
#     116
#     117     if deep or expr.is_Add or expr.is_Mul and _y not in expr.args:
# --> 118         expr = expr.func(*[recurse(w) for w in expr.args])
#     119
#     120     if expr.is_Pow:
#
# ~/.local/lib/python3.6/site-packages/sympy/simplify/powsimp.py in recurse(arg, **kwargs)
#     107         _force = kwargs.get('force', force)
#     108         _measure = kwargs.get('measure', measure)
# --> 109         return powsimp(arg, _deep, _combine, _force, _measure)
#     110
#     111     expr = sympify(expr)
#
# ~/.local/lib/python3.6/site-packages/sympy/simplify/powsimp.py in powsimp(expr, deep, combine, force, measure)
#     187             if b in skip:
#     188                 continue
# --> 189             bpos = b.is_positive or b.is_polar
#     190             if bpos:
#     191                 binv = 1/b
#
# ~/.local/lib/python3.6/site-packages/sympy/core/assumptions.py in getit(self)
#     456             if self._assumptions is self.default_assumptions:
#     457                 self._assumptions = self.default_assumptions.copy()
# --> 458             return _ask(fact, self)
#     459
#     460     getit.func_name = as_property(fact)
#
# ~/.local/lib/python3.6/site-packages/sympy/core/assumptions.py in _ask(fact, obj)
#     499         pass
#     500     else:
# --> 501         a = evaluate(obj)
#     502         if a is not None:
#     503             assumptions.deduce_all_facts(((fact, a),))
#
# ~/.local/lib/python3.6/site-packages/sympy/core/expr.py in _eval_is_positive(self)
#     859         if finite is False:
#     860             return False
# --> 861         extended_positive = self.is_extended_positive
#     862         if finite is True:
#     863             return extended_positive
#
# ~/.local/lib/python3.6/site-packages/sympy/core/assumptions.py in getit(self)
#     456             if self._assumptions is self.default_assumptions:
#     457                 self._assumptions = self.default_assumptions.copy()
# --> 458             return _ask(fact, self)
#     459
#     460     getit.func_name = as_property(fact)
#
# ~/.local/lib/python3.6/site-packages/sympy/core/assumptions.py in _ask(fact, obj)
#     499         pass
#     500     else:
# --> 501         a = evaluate(obj)
#     502         if a is not None:
#     503             assumptions.deduce_all_facts(((fact, a),))
#
# ~/.local/lib/python3.6/site-packages/sympy/core/add.py in _eval_is_extended_positive(self)
#     635         from sympy.core.exprtools import _monotonic_sign
#     636         if self.is_number:
# --> 637             return super()._eval_is_extended_positive()
#     638         c, a = self.as_coeff_Add()
#     639         if not c.is_zero:
#
# ~/.local/lib/python3.6/site-packages/sympy/core/expr.py in _eval_is_extended_positive(self)
#     911
#     912     def _eval_is_extended_positive(self):
# --> 913         return self._eval_is_extended_positive_negative(positive=True)
#     914
#     915     def _eval_is_extended_negative(self):
#
# ~/.local/lib/python3.6/site-packages/sympy/core/expr.py in _eval_is_extended_positive_negative(self, positive)
#     879         from sympy.polys.polyerrors import NotAlgebraic
#     880         if self.is_number:
# --> 881             if self.is_extended_real is False:
#     882                 return False
#     883
#
# ~/.local/lib/python3.6/site-packages/sympy/core/assumptions.py in getit(self)
#     456             if self._assumptions is self.default_assumptions:
#     457                 self._assumptions = self.default_assumptions.copy()
# --> 458             return _ask(fact, self)
#     459
#     460     getit.func_name = as_property(fact)
#
# ~/.local/lib/python3.6/site-packages/sympy/core/assumptions.py in _ask(fact, obj)
#     511             continue
#     512         if pk in handler_map:
# --> 513             _ask(pk, obj)
#     514
#     515             # we might have found the value of fact
#
# ~/.local/lib/python3.6/site-packages/sympy/core/assumptions.py in _ask(fact, obj)
#     511             continue
#     512         if pk in handler_map:
# --> 513             _ask(pk, obj)
#     514
#     515             # we might have found the value of fact
#
# ~/.local/lib/python3.6/site-packages/sympy/core/assumptions.py in _ask(fact, obj)
#     511             continue
#     512         if pk in handler_map:
# --> 513             _ask(pk, obj)
#     514
#     515             # we might have found the value of fact
#
# ~/.local/lib/python3.6/site-packages/sympy/core/assumptions.py in _ask(fact, obj)
#     499         pass
#     500     else:
# --> 501         a = evaluate(obj)
#     502         if a is not None:
#     503             assumptions.deduce_all_facts(((fact, a),))
#
# ~/.local/lib/python3.6/site-packages/sympy/core/add.py in _eval_is_extended_negative(self)
#     719         from sympy.core.exprtools import _monotonic_sign
#     720         if self.is_number:
# --> 721             return super()._eval_is_extended_negative()
#     722         c, a = self.as_coeff_Add()
#     723         if not c.is_zero:
#
# ~/.local/lib/python3.6/site-packages/sympy/core/expr.py in _eval_is_extended_negative(self)
#     914
#     915     def _eval_is_extended_negative(self):
# --> 916         return self._eval_is_extended_positive_negative(positive=False)
#     917
#     918     def _eval_interval(self, x, a, b):
#
# ~/.local/lib/python3.6/site-packages/sympy/core/expr.py in _eval_is_extended_positive_negative(self, positive)
#     884             # check to see that we can get a value
#     885             try:
# --> 886                 n2 = self._eval_evalf(2)
#     887             # XXX: This shouldn't be caught here
#     888             # Catches ValueError: hypsum() failed to converge to the requested
#
# ~/.local/lib/python3.6/site-packages/sympy/core/operations.py in _eval_evalf(self, prec)
#     346         args = []
#     347         for a in self.args:
# --> 348             newa = a._eval_evalf(prec)
#     349             if newa is None:
#     350                 args.append(a)
#
# ~/.local/lib/python3.6/site-packages/sympy/core/mul.py in _eval_evalf(self, prec)
#     674                 rv = -m
#     675         else:
# --> 676             rv = AssocOp._eval_evalf(self, prec)
#     677         if rv.is_number:
#     678             return rv.expand()
#
# ~/.local/lib/python3.6/site-packages/sympy/core/operations.py in _eval_evalf(self, prec)
#     346         args = []
#     347         for a in self.args:
# --> 348             newa = a._eval_evalf(prec)
#     349             if newa is None:
#     350                 args.append(a)
#
# ~/.local/lib/python3.6/site-packages/sympy/core/numbers.py in _eval_evalf(self, prec)
#    3377
#    3378     def _eval_evalf(self, prec):
# -> 3379         return Float._new(self._as_mpf_val(prec), prec)
#    3380
#    3381     def __eq__(self, other):
#
# TypeError: 'float' object is not callable

# %%
solve(1-0.997*px**2-0.997*py**2)
# Out:
# [{p_x: -1.00150338345971*sqrt(1 - 0.997*p_y**2)},
#  {p_x: 1.00150338345971*sqrt(1 - 0.997*p_y**2)}]

# %%
PY = np.linspace(0,0.5,10)
plt.plot(PY, -1.00150338345971*np.sqrt(1 - 0.997*PY**2))

# %%
solve()
